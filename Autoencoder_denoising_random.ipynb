# %%
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Model

import numpy as np
import matplotlib.pyplot as plt

# %%
BATCH_SIZE = 32
VAL_SIZE = 0.2
AMNT_BATCHS = 400
DATASET_SIZE = AMNT_BATCHS * BATCH_SIZE
EPOCHS = 40
NRO_MODELO = "modelo_randomPosta"

# %%
trainImages = keras.utils.image_dataset_from_directory(
    'places/',
    label_mode=None,
    image_size=(256,256),
    batch_size=BATCH_SIZE,
    shuffle=False).take(AMNT_BATCHS)

trainImages = trainImages.map( lambda x : x / 255 )

blurredTrainImages = keras.utils.image_dataset_from_directory(
    'blurredRandomPlaces/',
    label_mode=None,
    image_size=(256,256),
    batch_size=BATCH_SIZE,
    shuffle=False).take(AMNT_BATCHS)

blurredTrainImages = blurredTrainImages.map( lambda x : x / 255 )
# Out:
# Found 36500 files belonging to 1 classes.
# 2022-06-29 10:26:52.149020: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-29 10:26:52.195057: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-29 10:26:52.195487: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-29 10:26:52.196561: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-29 10:26:52.197708: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-29 10:26:52.197843: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-29 10:26:52.197952: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-29 10:26:52.686797: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-29 10:26:52.686959: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-29 10:26:52.687132: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-06-29 10:26:52.687282: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 12873 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Found 36500 files belonging to 1 classes.

# %%
valSplit = int( (DATASET_SIZE / BATCH_SIZE) * VAL_SIZE )

train =  tf.data.Dataset.zip((blurredTrainImages, trainImages))

datasetTrain = train.skip(valSplit)
datasetValidation = train.take(valSplit)

# %%
input = layers.Input(shape=(256, 256, 3))

# Encoder
x = layers.Conv2D(32, (5, 5), activation="relu", padding="same")(input)
x = layers.Conv2D(32, (5, 5), activation="relu", padding="same")(x)
x = layers.MaxPooling2D((2, 2), padding="same")(x)
x = layers.Conv2D(32, (5, 5), activation="relu", padding="same")(x)
x = layers.Conv2D(32, (5, 5), activation="relu", padding="same")(x)
x = layers.MaxPooling2D((2, 2), padding="same")(x)
x = layers.Conv2D(32, (5, 5), activation="relu", padding="same")(x)

# Decoder
x = layers.Conv2D(32, (5, 5), activation="relu", padding="same")(x)
x = layers.Conv2DTranspose(32, (3, 3), strides=2, activation="relu", padding="same")(x)
x = layers.Conv2D(32, (5, 5), activation="relu", padding="same")(x)
x = layers.Conv2D(32, (5, 5), activation="relu", padding="same")(x)
x = layers.Conv2DTranspose(32, (3, 3), strides=2, activation="relu", padding="same")(x)
x = layers.Conv2D(32, (5, 5), activation="relu", padding="same")(x)
x = layers.Conv2D(3, (5, 5), activation="sigmoid", padding="same")(x)


# Autoencoder
autoencoder = Model(input, x)
autoencoder.compile(optimizer="adam", loss="binary_crossentropy")

modelFile = open('checkpoints/' + NRO_MODELO + '/modelo.txt', 'w+')
autoencoder.summary(print_fn=lambda x: modelFile.write(x + '\n'))
modelFile.close()

# %%
def writeLog( file, epoch, log ):
    file.write(str(epoch) + ',' + str(log['loss'])+ ',' + str(log['val_loss']) + '\n')

# %%
modelCallback = tf.keras.callbacks.ModelCheckpoint(
        filepath='checkpoints/' + NRO_MODELO + '/model.ckpt',
        save_weights_only=True,
        verbose=1)

lossCkptFile = open('checkpoints/' + NRO_MODELO + '/loss.ckpt', 'a+')
lossCallback = keras.callbacks.LambdaCallback(on_epoch_end=lambda epoch, logs: writeLog( lossCkptFile, epoch, logs))

historia = autoencoder.fit(
    datasetTrain,
    epochs=EPOCHS,
    shuffle=True,
    validation_data=datasetValidation,
    callbacks = [modelCallback, lossCallback]
)

lossCkptFile.close()
# Out:
# Epoch 1/40
# 2022-06-29 10:27:28.303213: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8401
# 320/320 [==============================] - ETA: 0s - loss: 0.5572
# Epoch 1: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 83s 241ms/step - loss: 0.5572 - val_loss: 0.5452
# Epoch 2/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5527
# Epoch 2: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 79s 242ms/step - loss: 0.5527 - val_loss: 0.5402
# Epoch 3/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5340
# Epoch 3: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 79s 242ms/step - loss: 0.5340 - val_loss: 0.5321
# Epoch 4/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5271
# Epoch 4: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 80s 246ms/step - loss: 0.5271 - val_loss: 0.5292
# Epoch 5/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5261
# Epoch 5: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 80s 247ms/step - loss: 0.5261 - val_loss: 0.5288
# Epoch 6/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5257
# Epoch 6: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 79s 245ms/step - loss: 0.5257 - val_loss: 0.5308
# Epoch 7/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5254
# Epoch 7: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 81s 249ms/step - loss: 0.5254 - val_loss: 0.5277
# Epoch 8/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5244
# Epoch 8: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 81s 249ms/step - loss: 0.5244 - val_loss: 0.5272
# Epoch 9/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5235
# Epoch 9: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 79s 244ms/step - loss: 0.5235 - val_loss: 0.5259
# Epoch 10/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5235
# Epoch 10: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 79s 242ms/step - loss: 0.5235 - val_loss: 0.5258
# Epoch 11/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5231
# Epoch 11: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 79s 242ms/step - loss: 0.5231 - val_loss: 0.5275
# Epoch 12/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5225
# Epoch 12: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 79s 243ms/step - loss: 0.5225 - val_loss: 0.5252
# Epoch 13/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5224
# Epoch 13: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 79s 242ms/step - loss: 0.5224 - val_loss: 0.5250
# Epoch 14/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5259
# Epoch 14: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 81s 248ms/step - loss: 0.5259 - val_loss: 0.5272
# Epoch 15/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5234
# Epoch 15: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 79s 242ms/step - loss: 0.5234 - val_loss: 0.5253
# Epoch 16/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5222
# Epoch 16: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 81s 249ms/step - loss: 0.5222 - val_loss: 0.5250
# Epoch 17/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5218
# Epoch 17: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 81s 248ms/step - loss: 0.5218 - val_loss: 0.5257
# Epoch 18/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5217
# Epoch 18: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 82s 254ms/step - loss: 0.5217 - val_loss: 0.5246
# Epoch 19/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5216
# Epoch 19: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 82s 254ms/step - loss: 0.5216 - val_loss: 0.5241
# Epoch 20/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5213
# Epoch 20: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 80s 247ms/step - loss: 0.5213 - val_loss: 0.5239
# Epoch 21/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5211
# Epoch 21: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 81s 250ms/step - loss: 0.5211 - val_loss: 0.5236
# Epoch 22/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5208
# Epoch 22: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 81s 249ms/step - loss: 0.5208 - val_loss: 0.5238
# Epoch 23/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5205
# Epoch 23: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 79s 245ms/step - loss: 0.5205 - val_loss: 0.5236
# Epoch 24/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5205
# Epoch 24: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 80s 247ms/step - loss: 0.5205 - val_loss: 0.5234
# Epoch 25/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5199
# Epoch 25: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 79s 243ms/step - loss: 0.5199 - val_loss: 0.5227
# Epoch 26/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5199
# Epoch 26: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 79s 244ms/step - loss: 0.5199 - val_loss: 0.5228
# Epoch 27/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5197
# Epoch 27: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 79s 242ms/step - loss: 0.5197 - val_loss: 0.5225
# Epoch 28/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5196
# Epoch 28: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 80s 247ms/step - loss: 0.5196 - val_loss: 0.5226
# Epoch 29/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5196
# Epoch 29: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 79s 244ms/step - loss: 0.5196 - val_loss: 0.5224
# Epoch 30/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5196
# Epoch 30: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 81s 250ms/step - loss: 0.5196 - val_loss: 0.5222
# Epoch 31/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5193
# Epoch 31: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 83s 256ms/step - loss: 0.5193 - val_loss: 0.5221
# Epoch 32/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5189
# Epoch 32: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 83s 255ms/step - loss: 0.5189 - val_loss: 0.5221
# Epoch 33/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5190
# Epoch 33: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 84s 260ms/step - loss: 0.5190 - val_loss: 0.5221
# Epoch 34/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5188
# Epoch 34: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 80s 248ms/step - loss: 0.5188 - val_loss: 0.5231
# Epoch 35/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5187
# Epoch 35: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 80s 245ms/step - loss: 0.5187 - val_loss: 0.5216
# Epoch 36/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5187
# Epoch 36: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 80s 246ms/step - loss: 0.5187 - val_loss: 0.5257
# Epoch 37/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5187
# Epoch 37: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 79s 243ms/step - loss: 0.5187 - val_loss: 0.5214
# Epoch 38/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5184
# Epoch 38: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 79s 244ms/step - loss: 0.5184 - val_loss: 0.5213
# Epoch 39/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5182
# Epoch 39: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 79s 244ms/step - loss: 0.5182 - val_loss: 0.5213
# Epoch 40/40
# 320/320 [==============================] - ETA: 0s - loss: 0.5183
# Epoch 40: saving model to checkpoints/modelo_randomPosta/model.ckpt
# 320/320 [==============================] - 113s 350ms/step - loss: 0.5183 - val_loss: 0.5212

# %%
predictions = autoencoder.predict( datasetValidation.take(1) )
# Out:
# 1/1 [==============================] - 0s 344ms/step

# %%
def plotPrediccion( entrada, prediccion ):
    plt.figure(figsize=(20, 20))
    for i, (image1, image2) in enumerate(zip(entrada, prediccion)):
        ax = plt.subplot(2, 1, i + 1)
        image1Np = image1[0].numpy()
        #clip01 = lambda x : (x + np.ones_like(x) * np.abs( x.min() ) ) / (x + np.ones_like(x) * np.abs( x.min() ) ).max()
        
        plt.imshow( image1Np[0] )

        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        ax = plt.subplot(2, 1, i + 2)

        plt.imshow( image2 )

        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
    plt.show()

# %%
plotPrediccion( datasetValidation.take(1), predictions)

# %%
plt.plot(historia.history['loss'])
plt.plot(historia.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
